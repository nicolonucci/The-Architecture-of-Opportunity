# %%
# Youtube API keys
# Is suggested to use at least 8 keys if you use free keys
output_file = "youtube_keys.txt"

youtube_keys =[#insert your keys]

with open(output_file, "w") as f:
    for key in youtube_keys:
        f.write(key + "\n")

print(f"YouTube keys file created: {output_file}\nTotal keys: {len(youtube_keys)} ")
# Out:
# YouTube keys file created: youtube_keys.txt
# Total keys: 10
